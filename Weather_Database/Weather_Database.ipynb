# %%
# dependencies
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create set of random lat & long
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# create lists of lat & long
coordinates = list(lat_lngs)

# %%
# create list of cities
cities = []
# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the time library.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 1 | ossora
# Processing Record 3 of Set 1 | ateptsevo
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 1 | babushkin
# Processing Record 7 of Set 1 | tupelo
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | sucua
# Processing Record 10 of Set 1 | altay
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | hasaki
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | namatanai
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | nuuk
# Processing Record 20 of Set 1 | salalah
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | la ronge
# Processing Record 23 of Set 1 | stroud
# Processing Record 24 of Set 1 | newport
# Processing Record 25 of Set 1 | nelson bay
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | arkhangelskoye
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | higashine
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | tonj
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | cherskiy
# Processing Record 41 of Set 1 | talnakh
# Processing Record 42 of Set 1 | noumea
# Processing Record 43 of Set 1 | port-cartier
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 1 | beloha
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | flinders
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | mbarara
# Processing Record 3 of Set 2 | cabo san lucas
# Processing Record 4 of Set 2 | kavaratti
# Processing Record 5 of Set 2 | iquique
# Processing Record 6 of Set 2 | khatanga
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | stryn
# Processing Record 9 of Set 2 | khandyga
# Processing Record 10 of Set 2 | saldanha
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | isangel
# Processing Record 14 of Set 2 | vanimo
# Processing Record 15 of Set 2 | findlay
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | san quintin
# Processing Record 18 of Set 2 | sola
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | saverne
# Processing Record 21 of Set 2 | newnan
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | touros
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | mae sai
# Processing Record 26 of Set 2 | cidreira
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | viedma
# Processing Record 29 of Set 2 | iqaluit
# Processing Record 30 of Set 2 | kecsked
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | altamira
# Processing Record 33 of Set 2 | kopayhorod
# Processing Record 34 of Set 2 | shaoxing
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | olinda
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | celestun
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | mataura
# Processing Record 44 of Set 2 | cassilandia
# Processing Record 45 of Set 2 | kyshtovka
# Processing Record 46 of Set 2 | donskoye
# Processing Record 47 of Set 2 | rumonge
# Processing Record 48 of Set 2 | yellowknife
# Processing Record 49 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 2 | alihe
# Processing Record 1 of Set 3 | nagato
# Processing Record 2 of Set 3 | rovaniemi
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | vaini
# Processing Record 5 of Set 3 | banjar
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | concarneau
# Processing Record 9 of Set 3 | kholmogory
# Processing Record 10 of Set 3 | mangrol
# Processing Record 11 of Set 3 | san ramon
# Processing Record 12 of Set 3 | kaduqli
# Processing Record 13 of Set 3 | katsuura
# Processing Record 14 of Set 3 | eltham
# Processing Record 15 of Set 3 | pathein
# Processing Record 16 of Set 3 | svetlogorsk
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | saint-louis
# Processing Record 19 of Set 3 | jati
# Processing Record 20 of Set 3 | necochea
# Processing Record 21 of Set 3 | barinitas
# Processing Record 22 of Set 3 | keningau
# Processing Record 23 of Set 3 | hokitika
# Processing Record 24 of Set 3 | maracaju
# Processing Record 25 of Set 3 | byron bay
# Processing Record 26 of Set 3 | lorengau
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | hofn
# Processing Record 29 of Set 3 | coihaique
# Processing Record 30 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 3 | gat
# Processing Record 32 of Set 3 | acari
# Processing Record 33 of Set 3 | aksarka
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | ancud
# Processing Record 36 of Set 3 | bilibino
# Processing Record 37 of Set 3 | biltine
# Processing Record 38 of Set 3 | angoche
# Processing Record 39 of Set 3 | yulara
# Processing Record 40 of Set 3 | narsaq
# Processing Record 41 of Set 3 | mozhga
# Processing Record 42 of Set 3 | caluquembe
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | morant bay
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | xiashi
# Processing Record 47 of Set 3 | kavieng
# Processing Record 48 of Set 3 | kaitangata
# Processing Record 49 of Set 3 | fortuna foothills
# Processing Record 50 of Set 3 | port hedland
# Processing Record 1 of Set 4 | anaconda
# Processing Record 2 of Set 4 | paranga
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | beringovskiy
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | makakilo city
# Processing Record 7 of Set 4 | meulaboh
# Processing Record 8 of Set 4 | camacupa
# Processing Record 9 of Set 4 | manyana
# Processing Record 10 of Set 4 | pilna
# Processing Record 11 of Set 4 | muggia
# Processing Record 12 of Set 4 | veraval
# Processing Record 13 of Set 4 | smithers
# Processing Record 14 of Set 4 | yokote
# Processing Record 15 of Set 4 | cape town
# Processing Record 16 of Set 4 | san cristobal
# Processing Record 17 of Set 4 | kieta
# Processing Record 18 of Set 4 | malatya
# Processing Record 19 of Set 4 | lumeje
# Processing Record 20 of Set 4 | baley
# Processing Record 21 of Set 4 | karratha
# Processing Record 22 of Set 4 | malakal
# Processing Record 23 of Set 4 | yeppoon
# Processing Record 24 of Set 4 | luau
# Processing Record 25 of Set 4 | tromso
# Processing Record 26 of Set 4 | grindavik
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | russell
# Processing Record 29 of Set 4 | talaya
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | chimbote
# Processing Record 32 of Set 4 | uyuni
# Processing Record 33 of Set 4 | lerwick
# Processing Record 34 of Set 4 | hearst
# Processing Record 35 of Set 4 | saiha
# Processing Record 36 of Set 4 | georgetown
# Processing Record 37 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 4 | yambio
# Processing Record 39 of Set 4 | nantucket
# Processing Record 40 of Set 4 | gravdal
# Processing Record 41 of Set 4 | aquiraz
# Processing Record 42 of Set 4 | baykit
# Processing Record 43 of Set 4 | suntar
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | pinega
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | faanui
# Processing Record 48 of Set 4 | batesville
# Processing Record 49 of Set 4 | sovetskiy
# Processing Record 50 of Set 4 | fortuna
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | davidson
# Processing Record 3 of Set 5 | avarua
# Processing Record 4 of Set 5 | saskylakh
# Processing Record 5 of Set 5 | bubaque
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | homer
# Processing Record 8 of Set 5 | analipsis
# Processing Record 9 of Set 5 | maunabo
# Processing Record 10 of Set 5 | novoagansk
# Processing Record 11 of Set 5 | saint-augustin
# Processing Record 12 of Set 5 | upernavik
# Processing Record 13 of Set 5 | gushikawa
# Processing Record 14 of Set 5 | stawell
# Processing Record 15 of Set 5 | barsovo
# Processing Record 16 of Set 5 | tessalit
# Processing Record 17 of Set 5 | aswan
# Processing Record 18 of Set 5 | anadyr
# Processing Record 19 of Set 5 | evensk
# Processing Record 20 of Set 5 | chokurdakh
# Processing Record 21 of Set 5 | bereda
# Processing Record 22 of Set 5 | ngunguru
# Processing Record 23 of Set 5 | san jeronimo
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | nome
# Processing Record 26 of Set 5 | samarai
# Processing Record 27 of Set 5 | los llanos de aridane
# Processing Record 28 of Set 5 | maimon
# City not found. Skipping...
# Processing Record 29 of Set 5 | half moon bay
# Processing Record 30 of Set 5 | madimba
# Processing Record 31 of Set 5 | souillac
# Processing Record 32 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 33 of Set 5 | ballina
# Processing Record 34 of Set 5 | dalvik
# Processing Record 35 of Set 5 | prainha
# Processing Record 36 of Set 5 | imbituba
# Processing Record 37 of Set 5 | marawi
# Processing Record 38 of Set 5 | guaymas
# Processing Record 39 of Set 5 | ust-tsilma
# Processing Record 40 of Set 5 | nakhon phanom
# Processing Record 41 of Set 5 | northam
# Processing Record 42 of Set 5 | koumac
# Processing Record 43 of Set 5 | tura
# Processing Record 44 of Set 5 | pokosnoye
# Processing Record 45 of Set 5 | libertador general san martin
# Processing Record 46 of Set 5 | saint-francois
# Processing Record 47 of Set 5 | gopalpur
# Processing Record 48 of Set 5 | kasongo-lunda
# Processing Record 49 of Set 5 | naze
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | miles city
# Processing Record 2 of Set 6 | rongcheng
# Processing Record 3 of Set 6 | nhulunbuy
# Processing Record 4 of Set 6 | klaksvik
# Processing Record 5 of Set 6 | najran
# Processing Record 6 of Set 6 | aklavik
# Processing Record 7 of Set 6 | tayum
# Processing Record 8 of Set 6 | the valley
# Processing Record 9 of Set 6 | leh
# Processing Record 10 of Set 6 | samdari
# Processing Record 11 of Set 6 | namibe
# Processing Record 12 of Set 6 | takoradi
# Processing Record 13 of Set 6 | chapais
# Processing Record 14 of Set 6 | malindi
# Processing Record 15 of Set 6 | brae
# Processing Record 16 of Set 6 | sao joao da barra
# Processing Record 17 of Set 6 | sorland
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | avera
# Processing Record 20 of Set 6 | zaysan
# Processing Record 21 of Set 6 | dunedin
# Processing Record 22 of Set 6 | redwater
# Processing Record 23 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 24 of Set 6 | olafsvik
# Processing Record 25 of Set 6 | iskateley
# Processing Record 26 of Set 6 | jawhar
# Processing Record 27 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 6 | sur
# Processing Record 29 of Set 6 | dickinson
# Processing Record 30 of Set 6 | christchurch
# Processing Record 31 of Set 6 | hesperia
# Processing Record 32 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 6 | kisangani
# Processing Record 34 of Set 6 | nikolskoye
# Processing Record 35 of Set 6 | umuarama
# Processing Record 36 of Set 6 | taoudenni
# Processing Record 37 of Set 6 | stornoway
# Processing Record 38 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | kurilsk
# Processing Record 41 of Set 6 | sitarganj
# Processing Record 42 of Set 6 | sabang
# Processing Record 43 of Set 6 | jimenez
# Processing Record 44 of Set 6 | miranpur
# Processing Record 45 of Set 6 | palmer
# Processing Record 46 of Set 6 | vila franca do campo
# Processing Record 47 of Set 6 | kabalo
# Processing Record 48 of Set 6 | husavik
# Processing Record 49 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 50 of Set 6 | westport
# Processing Record 1 of Set 7 | makushino
# Processing Record 2 of Set 7 | vila velha
# Processing Record 3 of Set 7 | tsabong
# Processing Record 4 of Set 7 | bandarbeyla
# Processing Record 5 of Set 7 | umm lajj
# Processing Record 6 of Set 7 | salinas
# Processing Record 7 of Set 7 | batagay-alyta
# Processing Record 8 of Set 7 | broome
# Processing Record 9 of Set 7 | waldoboro
# Processing Record 10 of Set 7 | hualmay
# Processing Record 11 of Set 7 | huarmey
# Processing Record 12 of Set 7 | vao
# Processing Record 13 of Set 7 | yumen
# Processing Record 14 of Set 7 | gorontalo
# Processing Record 15 of Set 7 | ostrovnoy
# Processing Record 16 of Set 7 | roald
# Processing Record 17 of Set 7 | mayumba
# Processing Record 18 of Set 7 | linapacan
# City not found. Skipping...
# Processing Record 19 of Set 7 | tenenkou
# Processing Record 20 of Set 7 | broken hill
# Processing Record 21 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 7 | port-gentil
# Processing Record 23 of Set 7 | menongue
# Processing Record 24 of Set 7 | thunder bay
# Processing Record 25 of Set 7 | anloga
# Processing Record 26 of Set 7 | ilulissat
# Processing Record 27 of Set 7 | panguna
# Processing Record 28 of Set 7 | valparaiso
# Processing Record 29 of Set 7 | mirnyy
# Processing Record 30 of Set 7 | clyde river
# Processing Record 31 of Set 7 | svecha
# Processing Record 32 of Set 7 | arman
# Processing Record 33 of Set 7 | antanifotsy
# Processing Record 34 of Set 7 | roros
# Processing Record 35 of Set 7 | cockburn town
# Processing Record 36 of Set 7 | lagoa
# Processing Record 37 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 7 | caravelas
# Processing Record 39 of Set 7 | manzhouli
# Processing Record 40 of Set 7 | guanica
# Processing Record 41 of Set 7 | ampanihy
# Processing Record 42 of Set 7 | natal
# Processing Record 43 of Set 7 | dali
# Processing Record 44 of Set 7 | victoria
# Processing Record 45 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 7 | marzuq
# Processing Record 47 of Set 7 | grand-lahou
# Processing Record 48 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 7 | itarema
# Processing Record 50 of Set 7 | pachino
# Processing Record 1 of Set 8 | kholodnyy
# Processing Record 2 of Set 8 | kruisfontein
# Processing Record 3 of Set 8 | southampton
# Processing Record 4 of Set 8 | otjimbingwe
# Processing Record 5 of Set 8 | shebunino
# Processing Record 6 of Set 8 | sweetwater
# Processing Record 7 of Set 8 | gizo
# Processing Record 8 of Set 8 | maniitsoq
# Processing Record 9 of Set 8 | dutlwe
# Processing Record 10 of Set 8 | puga
# Processing Record 11 of Set 8 | talara
# Processing Record 12 of Set 8 | chuy
# Processing Record 13 of Set 8 | lubango
# Processing Record 14 of Set 8 | shediac
# Processing Record 15 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 8 | brindisi
# Processing Record 17 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 8 | caibarien
# Processing Record 19 of Set 8 | long xuyen
# Processing Record 20 of Set 8 | lebu
# Processing Record 21 of Set 8 | zabid
# Processing Record 22 of Set 8 | karachi
# Processing Record 23 of Set 8 | ojinaga
# Processing Record 24 of Set 8 | finschhafen
# Processing Record 25 of Set 8 | severo-kurilsk
# Processing Record 26 of Set 8 | moyale
# Processing Record 27 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 28 of Set 8 | gourcy
# Processing Record 29 of Set 8 | partizansk
# Processing Record 30 of Set 8 | urucui
# Processing Record 31 of Set 8 | henties bay
# Processing Record 32 of Set 8 | pisco
# Processing Record 33 of Set 8 | hamilton
# Processing Record 34 of Set 8 | zhezkazgan
# Processing Record 35 of Set 8 | kahului
# Processing Record 36 of Set 8 | tawang
# Processing Record 37 of Set 8 | gruiu
# Processing Record 38 of Set 8 | thompson
# Processing Record 39 of Set 8 | liepaja
# Processing Record 40 of Set 8 | pangnirtung
# Processing Record 41 of Set 8 | carmen
# Processing Record 42 of Set 8 | nizhnyaya poyma
# Processing Record 43 of Set 8 | taltal
# Processing Record 44 of Set 8 | marsabit
# Processing Record 45 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 8 | longyearbyen
# Processing Record 47 of Set 8 | almaznyy
# Processing Record 48 of Set 8 | bathsheba
# Processing Record 49 of Set 8 | syracuse
# Processing Record 50 of Set 8 | nabire
# Processing Record 1 of Set 9 | jetis
# Processing Record 2 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 9 | komsomolskiy
# Processing Record 4 of Set 9 | statesville
# Processing Record 5 of Set 9 | vysokogornyy
# Processing Record 6 of Set 9 | paita
# Processing Record 7 of Set 9 | champerico
# Processing Record 8 of Set 9 | hambantota
# Processing Record 9 of Set 9 | te anau
# Processing Record 10 of Set 9 | lucapa
# Processing Record 11 of Set 9 | upington
# Processing Record 12 of Set 9 | ouango
# Processing Record 13 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 14 of Set 9 | moron
# Processing Record 15 of Set 9 | ekhabi
# Processing Record 16 of Set 9 | labuhan
# Processing Record 17 of Set 9 | teguise
# Processing Record 18 of Set 9 | saint-pierre
# Processing Record 19 of Set 9 | gushi
# Processing Record 20 of Set 9 | sao miguel do araguaia
# Processing Record 21 of Set 9 | nur
# Processing Record 22 of Set 9 | tahta
# Processing Record 23 of Set 9 | deputatskiy
# Processing Record 24 of Set 9 | chimoio
# Processing Record 25 of Set 9 | tiksi
# Processing Record 26 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 9 | dingle
# Processing Record 28 of Set 9 | nurota
# Processing Record 29 of Set 9 | general roca
# Processing Record 30 of Set 9 | rapid city
# Processing Record 31 of Set 9 | talcahuano
# Processing Record 32 of Set 9 | cabedelo
# Processing Record 33 of Set 9 | pacific grove
# Processing Record 34 of Set 9 | benguela
# Processing Record 35 of Set 9 | tirumala
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | carutapera
# Processing Record 38 of Set 9 | ngorongoro
# Processing Record 39 of Set 9 | mangochi
# Processing Record 40 of Set 9 | columbus
# Processing Record 41 of Set 9 | bac lieu
# Processing Record 42 of Set 9 | san jose
# Processing Record 43 of Set 9 | batticaloa
# Processing Record 44 of Set 9 | seoul
# Processing Record 45 of Set 9 | tabas
# Processing Record 46 of Set 9 | sitka
# Processing Record 47 of Set 9 | itaueira
# Processing Record 48 of Set 9 | bay saint louis
# Processing Record 49 of Set 9 | samarinda
# Processing Record 50 of Set 9 | osoyoos
# Processing Record 1 of Set 10 | fare
# Processing Record 2 of Set 10 | morondava
# Processing Record 3 of Set 10 | alta floresta
# Processing Record 4 of Set 10 | poitiers
# Processing Record 5 of Set 10 | arequipa
# Processing Record 6 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 10 | vaitape
# Processing Record 8 of Set 10 | beyneu
# Processing Record 9 of Set 10 | ciudad guayana
# Processing Record 10 of Set 10 | kibala
# Processing Record 11 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 12 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 10 | richards bay
# Processing Record 14 of Set 10 | saint-georges
# Processing Record 15 of Set 10 | ambon
# Processing Record 16 of Set 10 | maragogi
# Processing Record 17 of Set 10 | sampit
# Processing Record 18 of Set 10 | mokobeng
# Processing Record 19 of Set 10 | baruun-urt
# Processing Record 20 of Set 10 | moose factory
# Processing Record 21 of Set 10 | kosovska mitrovica
# Processing Record 22 of Set 10 | zhangye
# Processing Record 23 of Set 10 | andenes
# Processing Record 24 of Set 10 | halifax
# Processing Record 25 of Set 10 | provideniya
# Processing Record 26 of Set 10 | pochutla
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | kirakira
# Processing Record 29 of Set 10 | presidencia roque saenz pena
# Processing Record 30 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 31 of Set 10 | port lincoln
# Processing Record 32 of Set 10 | teseney
# Processing Record 33 of Set 10 | bosanska kostajnica
# Processing Record 34 of Set 10 | dzaoudzi
# Processing Record 35 of Set 10 | bambous virieux
# Processing Record 36 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 10 | summerville
# Processing Record 38 of Set 10 | polunochnoye
# Processing Record 39 of Set 10 | makkaveyevo
# Processing Record 40 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 10 | cap malheureux
# Processing Record 42 of Set 10 | tete
# Processing Record 43 of Set 10 | ovar
# Processing Record 44 of Set 10 | norman wells
# Processing Record 45 of Set 10 | awjilah
# Processing Record 46 of Set 10 | yarensk
# Processing Record 47 of Set 10 | punta alta
# Processing Record 48 of Set 10 | bukama
# Processing Record 49 of Set 10 | kaliua
# Processing Record 50 of Set 10 | porto murtinho
# Processing Record 1 of Set 11 | cullman
# Processing Record 2 of Set 11 | hovd
# Processing Record 3 of Set 11 | saint-joseph
# Processing Record 4 of Set 11 | siruguppa
# Processing Record 5 of Set 11 | cubara
# Processing Record 6 of Set 11 | yialos
# City not found. Skipping...
# Processing Record 7 of Set 11 | egvekinot
# Processing Record 8 of Set 11 | atar
# Processing Record 9 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 11 | la ciotat
# Processing Record 11 of Set 11 | brigantine
# Processing Record 12 of Set 11 | dukat
# Processing Record 13 of Set 11 | luena
# Processing Record 14 of Set 11 | saryg-sep
# Processing Record 15 of Set 11 | coahuayana
# Processing Record 16 of Set 11 | port hardy
# Processing Record 17 of Set 11 | toamua
# City not found. Skipping...
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | poso
# Processing Record 20 of Set 11 | tual
# Processing Record 21 of Set 11 | buala
# Processing Record 22 of Set 11 | kalmunai
# Processing Record 23 of Set 11 | fort nelson
# Processing Record 24 of Set 11 | porto novo
# Processing Record 25 of Set 11 | muskegon
# Processing Record 26 of Set 11 | sassandra
# Processing Record 27 of Set 11 | bima
# Processing Record 28 of Set 11 | kutum
# Processing Record 29 of Set 11 | sao filipe
# Processing Record 30 of Set 11 | mount gambier
# Processing Record 31 of Set 11 | san carlos de bariloche
# Processing Record 32 of Set 11 | roma
# Processing Record 33 of Set 11 | sept-iles
# Processing Record 34 of Set 11 | keokuk
# Processing Record 35 of Set 11 | novikovo
# Processing Record 36 of Set 11 | birjand
# Processing Record 37 of Set 11 | rostock
# Processing Record 38 of Set 11 | tailai
# Processing Record 39 of Set 11 | madang
# Processing Record 40 of Set 11 | ankara
# Processing Record 41 of Set 11 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 42 of Set 11 | hay river
# Processing Record 43 of Set 11 | hohhot
# Processing Record 44 of Set 11 | upata
# Processing Record 45 of Set 11 | lianzhou
# Processing Record 46 of Set 11 | ottawa
# Processing Record 47 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 11 | lima
# Processing Record 49 of Set 11 | mantua
# Processing Record 50 of Set 11 | ahipara
# Processing Record 1 of Set 12 | norsup
# Processing Record 2 of Set 12 | gigmoto
# Processing Record 3 of Set 12 | vigrestad
# Processing Record 4 of Set 12 | lahaina
# Processing Record 5 of Set 12 | igarka
# Processing Record 6 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | dingzhou
# Processing Record 8 of Set 12 | faya
# Processing Record 9 of Set 12 | guarapari
# Processing Record 10 of Set 12 | terrace bay
# Processing Record 11 of Set 12 | meiganga
# Processing Record 12 of Set 12 | marand
# Processing Record 13 of Set 12 | ende
# Processing Record 14 of Set 12 | leningradskiy
# Processing Record 15 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 12 | kawalu
# Processing Record 17 of Set 12 | airth
# Processing Record 18 of Set 12 | carolina
# Processing Record 19 of Set 12 | talisayan
# Processing Record 20 of Set 12 | fairbanks
# Processing Record 21 of Set 12 | qui nhon
# Processing Record 22 of Set 12 | staroaleyskoye
# Processing Record 23 of Set 12 | changji
# Processing Record 24 of Set 12 | olga
# Processing Record 25 of Set 12 | clarence town
# Processing Record 26 of Set 12 | mitsamiouli
# Processing Record 27 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 12 | sokolo
# Processing Record 29 of Set 12 | suoyarvi
# Processing Record 30 of Set 12 | saint george
# Processing Record 31 of Set 12 | adrar
# Processing Record 32 of Set 12 | gordeyevka
# Processing Record 33 of Set 12 | castelletto sopra ticino
# Processing Record 34 of Set 12 | zyryanka
# Processing Record 35 of Set 12 | skibbereen
# Processing Record 36 of Set 12 | san luis
# Processing Record 37 of Set 12 | arawa
# Processing Record 38 of Set 12 | mayor pablo lagerenza
# Processing Record 39 of Set 12 | candelaria
# Processing Record 40 of Set 12 | lucea
# Processing Record 41 of Set 12 | maluso
# Processing Record 42 of Set 12 | lasa
# Processing Record 43 of Set 12 | paamiut
# Processing Record 44 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 45 of Set 12 | imeni poliny osipenko
# Processing Record 46 of Set 12 | sojat
# Processing Record 47 of Set 12 | kamarion
# Processing Record 48 of Set 12 | luanda
# Processing Record 49 of Set 12 | kamenka
# Processing Record 50 of Set 12 | onega
# Processing Record 1 of Set 13 | santa fe
# Processing Record 2 of Set 13 | yankton
# Processing Record 3 of Set 13 | hithadhoo
# Processing Record 4 of Set 13 | clearwater
# Processing Record 5 of Set 13 | sidi ali
# Processing Record 6 of Set 13 | sokoto
# Processing Record 7 of Set 13 | horizontina
# Processing Record 8 of Set 13 | blora
# Processing Record 9 of Set 13 | gayny
# Processing Record 10 of Set 13 | sao gabriel da cachoeira
# Processing Record 11 of Set 13 | davila
# Processing Record 12 of Set 13 | bemidji
# Processing Record 13 of Set 13 | eyl
# Processing Record 14 of Set 13 | kupino
# Processing Record 15 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 13 | kongolo
# Processing Record 17 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 18 of Set 13 | nalut
# Processing Record 19 of Set 13 | le port
# Processing Record 20 of Set 13 | sao felix do xingu
# Processing Record 21 of Set 13 | tarakan
# Processing Record 22 of Set 13 | darhan
# Processing Record 23 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 24 of Set 13 | ayia galini
# Processing Record 25 of Set 13 | chumikan
# Processing Record 26 of Set 13 | muncar
# Processing Record 27 of Set 13 | libreville
# Processing Record 28 of Set 13 | taree
# Processing Record 29 of Set 13 | iranshahr
# Processing Record 30 of Set 13 | puertollano
# Processing Record 31 of Set 13 | comodoro rivadavia
# Processing Record 32 of Set 13 | kolokani
# Processing Record 33 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 13 | nyakabindi
# Processing Record 35 of Set 13 | ouahigouya
# Processing Record 36 of Set 13 | sobolevo
# Processing Record 37 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 13 | niksic
# Processing Record 39 of Set 13 | amalapuram
# Processing Record 40 of Set 13 | les cayes
# Processing Record 41 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 13 | aripuana
# Processing Record 43 of Set 13 | parabel
# Processing Record 44 of Set 13 | camacha
# Processing Record 45 of Set 13 | soledad
# Processing Record 46 of Set 13 | gornozavodsk
# Processing Record 47 of Set 13 | nicolas bravo
# Processing Record 48 of Set 13 | harindanga
# Processing Record 49 of Set 13 | tres palos
# Processing Record 50 of Set 13 | sembakung
# Processing Record 1 of Set 14 | herat
# Processing Record 2 of Set 14 | yichun
# Processing Record 3 of Set 14 | constitucion
# Processing Record 4 of Set 14 | kiama
# Processing Record 5 of Set 14 | bull savanna
# Processing Record 6 of Set 14 | vereeniging
# Processing Record 7 of Set 14 | ulaangom
# Processing Record 8 of Set 14 | pitkyaranta
# Processing Record 9 of Set 14 | shelburne
# Processing Record 10 of Set 14 | gillette
# Processing Record 11 of Set 14 | hukuntsi
# Processing Record 12 of Set 14 | khasan
# Processing Record 13 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 14 | cuamba
# Processing Record 15 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 16 of Set 14 | kirksville
# Processing Record 17 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 18 of Set 14 | burnie
# Processing Record 19 of Set 14 | jalingo
# Processing Record 20 of Set 14 | lebedyn
# Processing Record 21 of Set 14 | pangody
# Processing Record 22 of Set 14 | belgrade
# Processing Record 23 of Set 14 | qujing
# Processing Record 24 of Set 14 | limon
# Processing Record 25 of Set 14 | vardo
# Processing Record 26 of Set 14 | praia da vitoria
# Processing Record 27 of Set 14 | pacifica
# Processing Record 28 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 14 | turukhansk
# Processing Record 30 of Set 14 | aleksandrovka
# Processing Record 31 of Set 14 | baijiantan
# Processing Record 32 of Set 14 | acajutla
# Processing Record 33 of Set 14 | berlevag
# Processing Record 34 of Set 14 | okhotsk
# Processing Record 35 of Set 14 | laguna
# Processing Record 36 of Set 14 | north augusta
# Processing Record 37 of Set 14 | sioux lookout
# Processing Record 38 of Set 14 | alofi
# Processing Record 39 of Set 14 | rio grande
# Processing Record 40 of Set 14 | college
# Processing Record 41 of Set 14 | harper
# Processing Record 42 of Set 14 | sterling
# Processing Record 43 of Set 14 | groton
# Processing Record 44 of Set 14 | bilma
# Processing Record 45 of Set 14 | mackay
# Processing Record 46 of Set 14 | soe
# Processing Record 47 of Set 14 | stillwater
# Processing Record 48 of Set 14 | betare oya
# Processing Record 49 of Set 14 | muros
# Processing Record 50 of Set 14 | ovre ardal
# Processing Record 1 of Set 15 | yamada
# Processing Record 2 of Set 15 | wawa
# Processing Record 3 of Set 15 | mareeba
# Processing Record 4 of Set 15 | boden
# Processing Record 5 of Set 15 | udachnyy
# Processing Record 6 of Set 15 | yatou
# Processing Record 7 of Set 15 | astana
# Processing Record 8 of Set 15 | tambura
# Processing Record 9 of Set 15 | maceio
# Processing Record 10 of Set 15 | nowy dwor mazowiecki
# Processing Record 11 of Set 15 | pangai
# Processing Record 12 of Set 15 | zarand
# Processing Record 13 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 14 of Set 15 | chkalovsk
# Processing Record 15 of Set 15 | tanabe
# Processing Record 16 of Set 15 | patitirion
# Processing Record 17 of Set 15 | duz
# City not found. Skipping...
# Processing Record 18 of Set 15 | sabinas
# Processing Record 19 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 20 of Set 15 | belaya gora
# Processing Record 21 of Set 15 | atherton
# Processing Record 22 of Set 15 | puerto escondido
# Processing Record 23 of Set 15 | ormara
# Processing Record 24 of Set 15 | thinadhoo
# Processing Record 25 of Set 15 | rosetta
# Processing Record 26 of Set 15 | ukiah
# Processing Record 27 of Set 15 | hinesburg
# Processing Record 28 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 15 | toamasina
# Processing Record 31 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 15 | saint anthony
# Processing Record 33 of Set 15 | nortelandia
# Processing Record 34 of Set 15 | leirvik
# Processing Record 35 of Set 15 | zhigansk
# Processing Record 36 of Set 15 | lakes entrance
# Processing Record 37 of Set 15 | muswellbrook
# Processing Record 38 of Set 15 | port augusta
# Processing Record 39 of Set 15 | marsa matruh
# Processing Record 40 of Set 15 | wuwei
# Processing Record 41 of Set 15 | vestmanna
# Processing Record 42 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 43 of Set 15 | pervomayskoye
# Processing Record 44 of Set 15 | harsud
# Processing Record 45 of Set 15 | el alto
# Processing Record 46 of Set 15 | santiago del estero
# Processing Record 47 of Set 15 | ust-nera
# Processing Record 48 of Set 15 | taos
# Processing Record 49 of Set 15 | poronaysk
# Processing Record 50 of Set 15 | sechenovo
# Processing Record 1 of Set 16 | paso del macho
# Processing Record 2 of Set 16 | nokia
# Processing Record 3 of Set 16 | kodinsk
# Processing Record 4 of Set 16 | yamoussoukro
# Processing Record 5 of Set 16 | vanderhoof
# Processing Record 6 of Set 16 | nouadhibou
# Processing Record 7 of Set 16 | jonava
# Processing Record 8 of Set 16 | negara
# Processing Record 9 of Set 16 | camocim
# Processing Record 10 of Set 16 | astara
# Processing Record 11 of Set 16 | prince rupert
# Processing Record 12 of Set 16 | muli
# Processing Record 13 of Set 16 | illapel
# Processing Record 14 of Set 16 | sechura
# Processing Record 15 of Set 16 | czestochowa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 699

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0          Ossora  59.2353  163.0719     35.08     overcast clouds        86
# 1       Ateptsevo  55.3236   36.7500     57.61       broken clouds        81
# 2       Babushkin  51.7122  105.8647     45.46           clear sky        76
# 3          Tupelo  34.2576  -88.7034     72.99       broken clouds        60
# 4         Rikitea -23.1203 -134.9692     77.47       broken clouds        83
# 5           Sucua  -2.4667  -78.1667     80.76          light rain        71
# 6           Altay  47.8667   88.1167     59.49       broken clouds        50
# 7           Kapaa  22.0752 -159.3190     75.18     overcast clouds        83
# 8          Hasaki  35.7333  140.8333     61.20     overcast clouds        90
# 9  Saint-Philippe -21.3585   55.7679     72.99    scattered clouds        83
#
#    Cloudiness  Wind Speed Country
# 0         100       10.92      RU
# 1          84        7.09      RU
# 2           3        6.44      RU
# 3          75       13.80      US
# 4          67       11.03      PF
# 5          75        4.23      EC
# 6          74        4.70      CN
# 7          96        5.01      US
# 8         100        7.14      JP
# 9          40       12.68      RE

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
